# %% [markdown]
# df = pd.DataFrame([['Math', 'en ligne', 2, False],['Data Processing','presentiel', 9, True],['Python', 'en ligne', 6, True],['SGBDR', 'en ligne', 5, False],['BD Spatiale', 'presentiel',4, False],['Rech Biblio', 'mixte', 8, True],['IA', 'presentiel', 4, True]])
#
#     Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff, Valider
#     Q2 : Selectioner un sous-ensemble de DF, dont les valeurs de la colonne 'Modal_Cours' sont égales à 'en ligne' et 'presentiel' (indication : utiliser la method .isin())
#     Q3 : Selectioner un sous-ensemble de DF, dont les valeurs de la colonne 'Coeff' sont dans compris entre 2 et 8 (indication : methode .between()).

# %%
import pandas as pd
df = pd.DataFrame([['Math', 'en ligne', 2, False],['Data Processing','presentiel', 9, True],['Python', 'en ligne', 6, True],['SGBDR', 'en ligne', 5, False],['BD Spatiale', 'presentiel',4, False],['Rech Biblio', 'mixte', 8, True],['IA', 'presentiel', 4, True]])
df
# Out:
#                  0           1  2      3
# 0             Math    en ligne  2  False
# 1  Data Processing  presentiel  9   True
# 2           Python    en ligne  6   True
# 3            SGBDR    en ligne  5  False
# 4      BD Spatiale  presentiel  4  False
# 5      Rech Biblio       mixte  8   True
# 6               IA  presentiel  4   True

# %% [raw]
# Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff, Valider

# %%
df.columns = ['Module', 'Modal_Cours', 'Coeff', 'Valider']
df
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False
# 4      BD Spatiale  presentiel      4    False
# 5      Rech Biblio       mixte      8     True
# 6               IA  presentiel      4     True

# %% [raw]
# Q2 : Selectioner un sous-ensemble de DF, dont les valeurs de la colonne 'Modal_Cours' sont égales à 'en ligne' et 'presentiel' (indication : utiliser la method .isin())

# %%
df1  = df['Modal_Cours'].isin(['presentiel','en ligne'])
df[df1]
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False
# 4      BD Spatiale  presentiel      4    False
# 6               IA  presentiel      4     True

# %% [raw]
# Q3 : Selectioner un sous-ensemble de DF, dont les valeurs de la colonne 'Coeff' sont dans compris entre 2 et 8 (indication : methode .between()).

# %%
df2= df["Coeff"].between(2, 8, inclusive = True)
df[df2]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   """Entry point for launching an IPython kernel.
#         Module Modal_Cours  Coeff  Valider
# 0         Math    en ligne      2    False
# 2       Python    en ligne      6     True
# 3        SGBDR    en ligne      5    False
# 4  BD Spatiale  presentiel      4    False
# 5  Rech Biblio       mixte      8     True
# 6           IA  presentiel      4     True

# %% [raw]
#     Quel est l'avantage de passer à des données de types x (float, integer, etc.) à des données de type 'Category' ? Et sur quels types d'observations pouvons nous appliquer cette conversion (l'intuition qui peut vous amener à prendre cette décision) ?
#     Soit  df = pd.DataFrame([['Math', 'en ligne', 2],['Data Processing','presentiel', 9],['Python', 'en ligne', 6], ['SGBDR', 'en ligne', 5],['BD Spatiale', 'presentiel',4],['Rech Biblio', 'mixte', 8], ['IA', 'presentiel', 4]])
#         Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff
#         Q2 : Afficher les informations de la df (indication : methode  .info())
#         Q3 : Laquelle des colonnes peut etre converti de type Category ? Justifier votre réponse
#         Q 4 : En affichant de nouveau les informations sur la DF, quelle remarque faites-vous ?

# %%
df = pd.DataFrame([['Math', 'en ligne', 2],['Data Processing','presentiel', 9],['Python', 'en ligne', 6], ['SGBDR', 'en ligne', 5],['BD Spatiale', 'presentiel',4],['Rech Biblio', 'mixte', 8], ['IA', 'presentiel', 4]])
df
# Out:
#                  0           1  2
# 0             Math    en ligne  2
# 1  Data Processing  presentiel  9
# 2           Python    en ligne  6
# 3            SGBDR    en ligne  5
# 4      BD Spatiale  presentiel  4
# 5      Rech Biblio       mixte  8
# 6               IA  presentiel  4

# %%
df.columns = ['Module', 'Modal_Cours', 'Coeff']
df
# Out:
#             Module Modal_Cours  Coeff
# 0             Math    en ligne      2
# 1  Data Processing  presentiel      9
# 2           Python    en ligne      6
# 3            SGBDR    en ligne      5
# 4      BD Spatiale  presentiel      4
# 5      Rech Biblio       mixte      8
# 6               IA  presentiel      4

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Module       7 non-null      object
#  1   Modal_Cours  7 non-null      object
#  2   Coeff        7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df = df["Module"].astype("category")
df
# Out:
# 0               Math
# 1    Data Processing
# 2             Python
# 3              SGBDR
# 4        BD Spatiale
# 5        Rech Biblio
# 6                 IA
# Name: Module, dtype: category
# Categories (7, object): ['BD Spatiale', 'Data Processing', 'IA', 'Math', 'Python', 'Rech Biblio', 'SGBDR']

# %%
df = df["Modal_Cours"].astype("category")
df
# Out:
# 0      en ligne
# 1    presentiel
# 2      en ligne
# 3      en ligne
# 4    presentiel
# 5         mixte
# 6    presentiel
# Name: Modal_Cours, dtype: category
# Categories (3, object): ['en ligne', 'mixte', 'presentiel']

# %%
df = df.astype('category')
df
# Out:
#             Module Modal_Cours Coeff
# 0             Math    en ligne     2
# 1  Data Processing  presentiel     9
# 2           Python    en ligne     6
# 3            SGBDR    en ligne     5
# 4      BD Spatiale  presentiel     4
# 5      Rech Biblio       mixte     8
# 6               IA  presentiel     4

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Module       7 non-null      category
#  1   Modal_Cours  7 non-null      category
#  2   Coeff        7 non-null      category
# dtypes: category(3)
# memory usage: 857.0 bytes

# %% [markdown]
# # Exercice du groupe C

# %% [raw]
#     df = pd.DataFrame([['Math', 'en ligne', 2, False],['Data Processing','presentiel', 9, True],['Python', 'en ligne', 6, True],['SGBDR', 'en ligne', 5, False],['BD Spatiale', 'presentiel',4, False],['Rech Biblio', 'mixte', 8, True],['IA', 'presentiel', 4, True]])
#
#         Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff, Valider
#         Q2 : Selectionner à la fois, le sous-ensemble de DF, dont les cours sont 'en ligne', dont les 'Coeff' sont sup à 7, et qui ont un statut 'Valider' (indication : operateur AND)
#         Q3 : Selectionner le sous-ensemble, dont les cours sont 'en ligne' ou dont les Coeff sont sup à 8 (indication : opérateur OR)
#         Q4 : Selectionner un sous ensemble de votre choix en utilisant simultanement les conditons AND et OR

# %%
df = pd.DataFrame([['Math', 'en ligne', 2, False],['Data Processing','presentiel', 9, True],['Python', 'en ligne', 6, True],['SGBDR', 'en ligne', 5, False],['BD Spatiale', 'presentiel',4, False],['Rech Biblio', 'mixte', 8, True],['IA', 'presentiel', 4, True]])
df
# Out:
#                  0           1  2      3
# 0             Math    en ligne  2  False
# 1  Data Processing  presentiel  9   True
# 2           Python    en ligne  6   True
# 3            SGBDR    en ligne  5  False
# 4      BD Spatiale  presentiel  4  False
# 5      Rech Biblio       mixte  8   True
# 6               IA  presentiel  4   True

# %% [markdown]
# Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff, Valider

# %%
df.columns = ['Module', 'Modal_Cours', 'Coeff', 'Valider']
df
# Out:
#             Module Modal_Cours  Coeff  Valider
# 0             Math    en ligne      2    False
# 1  Data Processing  presentiel      9     True
# 2           Python    en ligne      6     True
# 3            SGBDR    en ligne      5    False
# 4      BD Spatiale  presentiel      4    False
# 5      Rech Biblio       mixte      8     True
# 6               IA  presentiel      4     True

# %% [markdown]
# Q2 : Selectionner à la fois, le sous-ensemble de DF, dont les cours sont 'en ligne', dont les 'Coeff' sont sup à 7, et qui ont un statut 'Valider' (indication : operateur AND)

# %%
req1=df['Module']=='en ligne'
req2=df['Coeff']>7
req3=df['Valider']==True
req=df[req1&req2&req3]
req
# Out:
# Empty DataFrame
# Columns: [Module, Modal_Cours, Coeff, Valider]
# Index: []

# %% [markdown]
# Q3 : Selectionner le sous-ensemble, dont les cours sont 'en ligne' ou dont les Coeff sont sup à 8 (indication : opérateur OR)

# %%
req4=df['Modal_cours']=='presentiel'
req5=df['Coeff']>2
req6=df['Valider']==False
req=df[req6&(req7 | req8)]
req

# %% [markdown]
# # Groupe A  : Correction du 02082021 par M.Kafando

# %% [markdown]
#     Quel est l'avantage de passer à des données de types x (float, integer, etc.) à des données de type 'Category' ? Et sur quels types d'observations pouvons nous appliquer cette conversion (l'intuition qui peut vous amener à prendre cette décision) ?
#     Soit  df = pd.DataFrame([['Math', 'en ligne', 2],['Data Processing','presentiel', 9],['Python', 'en ligne', 6], ['SGBDR', 'en ligne', 5],['BD Spatiale', 'presentiel',4],['Rech Biblio', 'mixte', 8], ['IA', 'presentiel', 4]])
#         Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff
#         Q2 : Afficher les informations de la df (indication : methode  .info())
#         Q3 : Laquelle des colonnes peut etre converti de type Category ? Justifier votre réponse
#         Q 4 : En affichant de nouveau les informations sur la DF, quelle remarque faites-vous ?

# %%
import pandas as pd
df = pd.DataFrame([['Math', 'en ligne', 2],['Data Processing','presentiel', 9],['Python', 'en ligne', 6], ['SGBDR', 'en ligne', 5],['BD Spatiale', 'presentiel',4],['Rech Biblio', 'mixte', 8], ['IA', 'presentiel', 4]])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
#  1   1       7 non-null      object
#  2   2       7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# Q1 : renommer les colonnes respectivement avec les noms suivants : Module, Modal_Cours, Coeff

# %%
df.columns = ['Module', 'Modal_Cours', 'Coeff']
df
# Out:
#             Module Modal_Cours  Coeff
# 0             Math    en ligne      2
# 1  Data Processing  presentiel      9
# 2           Python    en ligne      6
# 3            SGBDR    en ligne      5
# 4      BD Spatiale  presentiel      4
# 5      Rech Biblio       mixte      8
# 6               IA  presentiel      4

# %%
Q2 : Afficher les informations de la df (indication : methode  .info())

# %%
df.info(verbose=True) #resumé detaillé avec le type de chaque colonne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Module       7 non-null      object
#  1   Modal_Cours  7 non-null      object
#  2   Coeff        7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df.info() #équvaut à verbose=True
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Module       7 non-null      object
#  1   Modal_Cours  7 non-null      object
#  2   Coeff        7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df.info(verbose=False) #resumé simple sans details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Columns: 3 entries, Module to Coeff
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# Q3 : Laquelle des colonnes peut etre converti de type Category ? Justifier votre réponse

# %%
df["Modal_Cours"]=df["Modal_Cours"].astype("category")
df
# Out:
#             Module Modal_Cours  Coeff
# 0             Math    en ligne      2
# 1  Data Processing  presentiel      9
# 2           Python    en ligne      6
# 3            SGBDR    en ligne      5
# 4      BD Spatiale  presentiel      4
# 5      Rech Biblio       mixte      8
# 6               IA  presentiel      4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Module       7 non-null      object
#  1   Modal_Cours  7 non-null      category
#  2   Coeff        7 non-null      int64
# dtypes: category(1), int64(1), object(1)
# memory usage: 379.0+ bytes

# %% [markdown]
# Quel est l'avantage de passer à des données de types x (float, integer, etc.) à des données de type 'Category' ?

# %%
# Avantage de la conversion de str en cat optimisation d'espace memoire

# %% [markdown]
# Q 4 : En affichant de nouveau les informations sur la DF, quelle remarque faites-vous ?

# %% [raw]
# Req : La conversion des type object en categorie permet de diminuer l'sage de la memoire

# %% [markdown]
# # Groupe E : Corrigé du 02082021 par M.Kafando

# %% [markdown]
#     df = pd.DataFrame([['M. YARA','Math', 'en ligne', 2, False],['M. MAIGA', 'Data Processing','presentiel', 9, True],['M. SANOU', 'Python', 'en ligne', 6, True],['M. ILBOUDO', 'SGBDR', 'en ligne', 5, False],['M. TAPSOBA', 'BD Spatiale', 'presentiel',4, False],['Mme. ROUAMBA', 'Rech Biblio', 'mixte', 8, True],['M. ILBOUDO', 'IA', 'presentiel', 4, True], ['M. BAZIE', 'SGBDR', 'presentiel', 4, True]])
#
#         Q1 : renommer les colonnes respectivement avec les noms suivants : Nom, Module, Modal_Cours, Coeff, Valider
#         Q2 : Redefinissez la colonne 'Nom' comme étant l'index de DF (indication : method .set_index()). Comment faire pour retrouver la DF initiale avec l'index par defaut ?
#         Q3 : Selectionner le sous-ensemble de DF contenant uniquement les informations sur les étudiants ayant les noms : M. ILBOUDO et M. BAZIE (indication : methode .loc())
#         Q4 : En utilisant .loc(), selectionner le sous-ensemble allant de M. YARA à M. TAPSOBA, et qui prend en compte uniquement les colonnes Coeff et Valider (vous pouvez faire pour Modal_Cours à Valider)
#         Q5 : Utiliser .iloc() pour recuperer le sous-ensemble composé des index d'indices ou de position 0 à 6, avec un pas de 2

# %%
import pandas as pd
df = pd.DataFrame([['M. YARA','Math', 'en ligne', 2, False],['M. MAIGA', 'Data Processing','presentiel', 9, True],['M. SANOU', 'Python', 'en ligne', 6, True],['M. ILBOUDO', 'SGBDR', 'en ligne', 5, False],['M. TAPSOBA', 'BD Spatiale', 'presentiel',4, False],['Mme. ROUAMBA', 'Rech Biblio', 'mixte', 8, True],['M. ILBOUDO', 'IA', 'presentiel', 4, True], ['M. BAZIE', 'SGBDR', 'presentiel', 4, True]])
df
# Out:
#               0                1           2  3      4
# 0       M. YARA             Math    en ligne  2  False
# 1      M. MAIGA  Data Processing  presentiel  9   True
# 2      M. SANOU           Python    en ligne  6   True
# 3    M. ILBOUDO            SGBDR    en ligne  5  False
# 4    M. TAPSOBA      BD Spatiale  presentiel  4  False
# 5  Mme. ROUAMBA      Rech Biblio       mixte  8   True
# 6    M. ILBOUDO               IA  presentiel  4   True
# 7      M. BAZIE            SGBDR  presentiel  4   True

# %% [markdown]
# Q1 : renommer les colonnes respectivement avec les noms suivants : Nom, Module, Modal_Cours, Coeff, Valider

# %%
df.columns = ['Nom','Module', 'Modal_Cours', 'Coeff', 'Valider']
df
# Out:
#             Nom           Module Modal_Cours  Coeff  Valider
# 0       M. YARA             Math    en ligne      2    False
# 1      M. MAIGA  Data Processing  presentiel      9     True
# 2      M. SANOU           Python    en ligne      6     True
# 3    M. ILBOUDO            SGBDR    en ligne      5    False
# 4    M. TAPSOBA      BD Spatiale  presentiel      4    False
# 5  Mme. ROUAMBA      Rech Biblio       mixte      8     True
# 6    M. ILBOUDO               IA  presentiel      4     True
# 7      M. BAZIE            SGBDR  presentiel      4     True

# %% [markdown]
# Q2 : Redefinissez la colonne 'Nom' comme étant l'index de DF (indication : method .set_index()). Comment faire pour retrouver la DF initiale avec l'index par defaut ?

# %%
df.set_index('Nom', inplace  = True)
df
# Out:
#                        Module Modal_Cours  Coeff  Valider
# Nom
# M. YARA                  Math    en ligne      2    False
# M. MAIGA      Data Processing  presentiel      9     True
# M. SANOU               Python    en ligne      6     True
# M. ILBOUDO              SGBDR    en ligne      5    False
# M. TAPSOBA        BD Spatiale  presentiel      4    False
# Mme. ROUAMBA      Rech Biblio       mixte      8     True
# M. ILBOUDO                 IA  presentiel      4     True
# M. BAZIE                SGBDR  presentiel      4     True

# %%
df=df.reset_index()
df
# Out:
#    index           Nom           Module Modal_Cours  Coeff  Valider
# 0      0       M. YARA             Math    en ligne      2    False
# 1      1      M. MAIGA  Data Processing  presentiel      9     True
# 2      2      M. SANOU           Python    en ligne      6     True
# 3      3    M. ILBOUDO            SGBDR    en ligne      5    False
# 4      4    M. TAPSOBA      BD Spatiale  presentiel      4    False
# 5      5  Mme. ROUAMBA      Rech Biblio       mixte      8     True
# 6      6    M. ILBOUDO               IA  presentiel      4     True
# 7      7      M. BAZIE            SGBDR  presentiel      4     True

# %% [markdown]
# Q3 : Selectionner le sous-ensemble de DF contenant uniquement les informations sur les étudiants ayant les noms : M. ILBOUDO et M. BAZIE (indication : methode .loc())

# %%
df.loc[[3,7]]
# Out:
#    index         Nom Module Modal_Cours  Coeff  Valider
# 3      3  M. ILBOUDO  SGBDR    en ligne      5    False
# 7      7    M. BAZIE  SGBDR  presentiel      4     True

# %%
df.set_index('Nom', inplace  = True)
df.loc[['M. ILBOUDO','M. BAZIE']]
# Out:
#             index Module Modal_Cours  Coeff  Valider
# Nom
# M. ILBOUDO      3  SGBDR    en ligne      5    False
# M. ILBOUDO      6     IA  presentiel      4     True
# M. BAZIE        7  SGBDR  presentiel      4     True

# %% [markdown]
# Q4 : En utilisant .loc(), selectionner le sous-ensemble allant de M. YARA à M. TAPSOBA, et qui prend en compte uniquement les colonnes Coeff et Valider (vous pouvez faire pour Modal_Cours à Valider)

# %%
df.loc[['M. YARA','M. TAPSOBA'],['Coeff','Valider']]
# Out:
#             Coeff  Valider
# Nom
# M. YARA         2    False
# M. TAPSOBA      4    False

# %%
df=df.reset_index()
df
# Out:
#             Nom  index           Module Modal_Cours  Coeff  Valider
# 0       M. YARA      0             Math    en ligne      2    False
# 1      M. MAIGA      1  Data Processing  presentiel      9     True
# 2      M. SANOU      2           Python    en ligne      6     True
# 3    M. ILBOUDO      3            SGBDR    en ligne      5    False
# 4    M. TAPSOBA      4      BD Spatiale  presentiel      4    False
# 5  Mme. ROUAMBA      5      Rech Biblio       mixte      8     True
# 6    M. ILBOUDO      6               IA  presentiel      4     True
# 7      M. BAZIE      7            SGBDR  presentiel      4     True

# %% [markdown]
# Q5 : Utiliser .iloc() pour recuperer le sous-ensemble composé des index d'indices ou de position 0 à 6, avec un pas de 2

# %%
df.reset_index() 
df.iloc[0:6:2]
# Out:
#           Nom  index       Module Modal_Cours  Coeff  Valider
# 0     M. YARA      0         Math    en ligne      2    False
# 2    M. SANOU      2       Python    en ligne      6     True
# 4  M. TAPSOBA      4  BD Spatiale  presentiel      4    False
